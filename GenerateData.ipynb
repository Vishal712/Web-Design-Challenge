# %%
import pandas as pd

# %% [markdown]
# In order to get the data ready to export to an html code, we must first get it to a proper format with 10 columns.

# %%
data_table = pd.read_csv("Resources/city_data.csv")
data_table = data_table.drop(["Unnamed: 0", "Unnamed: 0.1"], axis = 1)
data_table = data_table.reset_index()
data_table = data_table.rename(columns={"index": "City_ID"})

# %%
data_table
# Out:
#      City_ID           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          0  pacific grove  36.62 -121.92     70.00        56          40
# 1          1         laguna  38.42 -121.42     84.00        39           1
# 2          2           miri   4.41  114.01     75.20        94          40
# 3          3        veraval  20.90   70.37     83.28        82         100
# 4          4         dikson  73.51   80.55     39.96        93          27
# ..       ...            ...    ...     ...       ...       ...         ...
# 568      568       khorixas -20.37   14.97     60.87        29           0
# 569      569  santa rosalia  27.32 -112.28     88.95        55          73
# 570      570          arman  59.70  150.17     59.20        65          34
# 571      571        bubaque  11.28  -15.83     80.85        82          99
# 572      572     lavassaare  58.51   24.39     57.00        70           0
#
#      Wind Speed Country        Date
# ...

# %%
html_code = data_table.to_html()
print(html_code)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>pacific grove</td>
#       <td>36.62</td>
#       <td>-121.92</td>
#       <td>70.00</td>
#       <td>56</td>
#       <td>40</td>
#       <td>14.99</td>
#       <td>US</td>
#       <td>1595451206</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>laguna</td>
#       <td>38.42</td>
#       <td>-121.42</td>
#       <td>84.00</td>
#       <td>39</td>
#       <td>1</td>
#       <td>12.75</td>
#       <td>US</td>
#       <td>1595451206</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>miri</td>
# ...
